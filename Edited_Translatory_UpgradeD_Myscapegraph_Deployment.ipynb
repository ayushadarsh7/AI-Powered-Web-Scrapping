# %%
# %%capture
# Install or upgrade scrapegraphai library, which is used for web scraping and data extraction
# !pip install scrapegraphai --upgrade

# Install chromium-chromedriver, which is a dependency for some web scraping libraries
# !apt install chromium-chromedriver

# Install nest_asyncio library, which is used to enable nested async/await syntax in Python
# !pip install nest_asyncio

# Install playwright library, which is a browser automation framework for web scraping and testing
# !pip install playwright

# Install the browsers required for playwright (e.g. chromium, firefox, webkit)
# !playwright install

# !pip install ipywidgets

# !pip install translate

# !pip install textblob

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
GOOGLE_API_KEY = "AIzaSyB5T_QRbSSZ4Wgy7oSPMsflO_9I45L6zVg"

# %%
from scrapegraphai.graphs import SmartScraperGraph

# %%
from scrapegraphai.graphs import SmartScraperGraph

# %%
graph_config = {
    "llm": {
        "api_key": GOOGLE_API_KEY,
        "model": "gemini-pro",
    },
    "verbose":True
}

# %%
"""
smart_scraper_graph = SmartScraperGraph(
    prompt="List me all the news with their description. Separate them by category.",
    # also accepts a string with the already downloaded HTML code
    source="https://www.wired.com/category/science/",
    config=graph_config
)
"""
# Out:
# '\nsmart_scraper_graph = SmartScraperGraph(\n    prompt="List me all the news with their description. Separate them by category.",\n    # also accepts a string with the already downloaded HTML code\n    source="https://www.wired.com/category/science/",\n    config=graph_config\n)\n'

# %%
# !pip install voila
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 30.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.9/105.9 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.4/383.4 kB 37.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 15.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 9.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.24.0
#     Uninstalling jupyter-server-1.24.0:
#       Successfully uninstalled jupyter-server-1.24.0
# ...

# %%
'''
import json
from scrapegraphai.graphs import SmartScraperGraph
from ipywidgets import Text

graph_config = {
    "llm": {
        "api_key": "AIzaSyApySdSPcvJJXhcbeAP14UcL8S4ZGvl85g",
        "model": "gemini-pro",
    },
    "verbose": True
}

prompt = Text(value="Enter your prompt:", placeholder="List the headings with news, separate them by category.", description="Prompt:")
source = Text(value="Enter your source:", placeholder="https://www.nature.com/", description="Source:")

display(prompt)
display(source)

def smart_scraper_app(b):
    prompt_value = prompt.value
    source_value = source.value

    smart_scraper_graph = SmartScraperGraph(
        prompt=prompt_value,
        source=source_value,
        config=graph_config
    )

    result = smart_scraper_graph.run()

    output = json.dumps(result, indent=2)

    line_list = output.split("\n")  # Sort of line replacing "\n" with a new line

    for line in line_list:
        print(line)

from ipywidgets import Button
button = Button(description="Run")
display(button)

button.on_click(smart_scraper_app)
'''
# Out:
# '\nimport json\nfrom scrapegraphai.graphs import SmartScraperGraph\nfrom ipywidgets import Text\n\ngraph_config = {\n    "llm": {\n        "api_key": "AIzaSyApySdSPcvJJXhcbeAP14UcL8S4ZGvl85g",\n        "model": "gemini-pro",\n    },\n    "verbose": True\n}\n\nprompt = Text(value="Enter your prompt:", placeholder="List the headings with news, separate them by category.", description="Prompt:")\nsource = Text(value="Enter your source:", placeholder="https://www.nature.com/", description="Source:")\n\ndisplay(prompt)\ndisplay(source)\n\ndef smart_scraper_app(b):\n    prompt_value = prompt.value\n    source_value = source.value\n\n    smart_scraper_graph = SmartScraperGraph(\n        prompt=prompt_value,\n        source=source_value,\n        config=graph_config\n    )\n\n    result = smart_scraper_graph.run()\n\n    output = json.dumps(result, indent=2)\n\n    line_list = output.split("\n")  # Sort of line replacing "\n" with a new line\n\n    for line in line_list:\n        print(line)
# ...

# %%
'''
import json
from scrapegraphai.graphs import SmartScraperGraph
from ipywidgets import Text, IntText, Button

# Configuration for the SmartScraperGraph
graph_config = {
    "llm": {
        "api_key": "AIzaSyApySdSPcvJJXhcbeAP14UcL8S4ZGvl85g",
        "model": "gemini-pro",
    },
    "verbose": True
}

# Widget to input the number of sources
num_sources_widget = IntText(value=1, description="Number of sources:")
display(num_sources_widget)

# List to store the source URL widgets
sources_widgets = []

# Function to create source URL widgets based on the number of sources
def on_num_sources_change(change):
    # Get the new number of sources
    num_sources = change.new
    # Clear the list of source URL widgets
    sources_widgets.clear()
    # Create a new source URL widget for each source
    for i in range(num_sources):
        source_widget = Text(value="", placeholder=f"Enter source {i+1} URL:", description=f"Source {i+1}:")
        sources_widgets.append(source_widget)
        display(source_widget)

# Observe changes to the number of sources widget and call the on_num_sources_change function
num_sources_widget.observe(on_num_sources_change, names='value')

# Widget to input the prompt
prompt_widget = Text(value="", placeholder="Enter your prompt:", description="Prompt:")
display(prompt_widget)

# Function to run the SmartScraperGraph for each source URL
def smart_scraper_app(b):
    # Get the prompt value
    prompt_value = prompt_widget.value
    # List to store the results
    results = []
    # Loop through each source URL widget
    for source_widget in sources_widgets:
        # Get the source URL value
        source_value = source_widget.value
        # Create a SmartScraperGraph instance
        smart_scraper_graph = SmartScraperGraph(
            prompt=prompt_value,
            source=source_value,
            config=graph_config
        )
        # Run the SmartScraperGraph and get the result
        result = smart_scraper_graph.run()
        # Append the result to the results list
        results.append(result)
    # Convert the results list to JSON and print it
    output = json.dumps(results, indent=2)
    print(output)

# Button to run the smart_scraper_app function
button = Button(description="Run")
display(button)

# Set the button's on_click event to call the smart_scraper_app function
button.on_click(smart_scraper_app)

'''
# Out:
# IntText(value=1, description='Number of sources:')
# Text(value='', description='Prompt:', placeholder='Enter your prompt:')
# Button(description='Run', style=ButtonStyle())

# %%
'''
import json
from scrapegraphai.graphs import SmartScraperGraph
from ipywidgets import Text, IntText, Button, Checkbox
from translate import Translator

# Configuration for the SmartScraperGraph
graph_config = {
    "llm": {
        "api_key": "AIzaSyApySdSPcvJJXhcbeAP14UcL8S4ZGvl85g",
        "model": "gemini-pro",
    },
    "verbose": True
}

# Widget to input the number of sources
num_sources_widget = IntText(value=1, description="Number of sources:")
display(num_sources_widget)

# List to store the source URL widgets
sources_widgets = []

# Function to create source URL widgets based on the number of sources
def on_num_sources_change(change):
    # Get the new number of sources
    num_sources = change.new
    # Clear the list of source URL widgets
    sources_widgets.clear()
    # Create a new source URL widget for each source
    for i in range(num_sources):
        source_widget = Text(value="", placeholder=f"Enter source {i+1} URL:", description=f"Source {i+1}:")
        sources_widgets.append(source_widget)
        display(source_widget)

# Observe changes to the number of sources widget and call the on_num_sources_change function
num_sources_widget.observe(on_num_sources_change, names='value')

# Widget to input the prompt
prompt_widget = Text(value="", placeholder="Enter your prompt:", description="Prompt:")
display(prompt_widget)

# Widget to select whether to translate the prompt
translate_checkbox = Checkbox(value=False, description="Translate prompt:")
display(translate_checkbox)

# Widget to input the language of the prompt (if translation is selected)
language_widget = Text(value="", placeholder="Enter language of prompt (e.g. ko for Korean):", description="Language:")
display(language_widget)

# Function to run the SmartScraperGraph for each source URL
def smart_scraper_app(b):
    # Get the prompt value
    prompt_value = prompt_widget.value
    # Check if translation is selected
    if translate_checkbox.value:
        # Get the language value
        language_value = language_widget.value
        # Create a Translator instance
        translator = Translator(from_lang=language_value, to_lang="en")
        # Translate the prompt
        prompt_value = translator.translate(prompt_value)
    # List to store the results
    results = []
    # Loop through each source URL widget
    for source_widget in sources_widgets:
        # Get the source URL value
        source_value = source_widget.value
        # Create a SmartScraperGraph instance
        smart_scraper_graph = SmartScraperGraph(
            prompt=prompt_value,
            source=source_value,
            config=graph_config
        )
        # Run the SmartScraperGraph and get the result
        result = smart_scraper_graph.run()
        # Append the result to the results list
        results.append(result)
    # Convert the results list to JSON and print it
    output = json.dumps(results, indent=2)
    print(output)

# Button to run the smart_scraper_app function
button = Button(description="Run")
display(button)

# Set the button's on_click event to call the smart_scraper_app function
button.on_click(smart_scraper_app)

'''
# Out:
# IntText(value=1, description='Number of sources:')
# Text(value='', description='Prompt:', placeholder='Enter your prompt:')
# Checkbox(value=False, description='Translate prompt:')
# Text(value='', description='Language:', placeholder='Enter language of prompt (e.g. ko for Korean):')
# Button(description='Run', style=ButtonStyle())
# Text(value='', description='Source 1:', placeholder='Enter source 1 URL:')
# Text(value='', description='Source 2:', placeholder='Enter source 2 URL:')
# --- Executing Fetch Node ---
# --- Executing Parse Node ---
# --- Executing RAG Node ---
# --- (updated chunks metadata) ---
# --- (tokens compressed and vector stored) ---
# --- Executing GenerateAnswer Node ---
# Processing chunks: 100%|██████████| 1/1 [00:00<00:00, 1817.29it/s]
# --- Executing Fetch Node ---
# --- Executing Parse Node ---
# --- Executing RAG Node ---
# --- (updated chunks metadata) ---
# --- (tokens compressed and vector stored) ---
# --- Executing GenerateAnswer Node ---
# ...

# %%
import json
from scrapegraphai.graphs import SmartScraperGraph
from ipywidgets import Text, IntText, Button, Checkbox
from translate import Translator

# Configuration for the SmartScraperGraph
graph_config = {
    "llm": {
        "api_key": "AIzaSyB5T_QRbSSZ4Wgy7oSPMsflO_9I45L6zVg",
        "model": "gemini-pro",
    },
    "verbose": True
}

# Widget to input the number of sources
num_sources_widget = IntText(value=1, description="Number of sources:")
display(num_sources_widget)

# List to store the source URL widgets
sources_widgets = []

# Function to create source URL widgets based on the number of sources
def on_num_sources_change(change):
    # Get the new number of sources
    num_sources = change.new
    # Clear the list of source URL widgets
    sources_widgets.clear()
    # Create a new source URL widget for each source
    for i in range(num_sources):
        source_widget = Text(value="", placeholder=f"Enter source {i+1} URL:", description=f"Source {i+1}:")
        sources_widgets.append(source_widget)
        display(source_widget)

# Observe changes to the number of sources widget and call the on_num_sources_change function
num_sources_widget.observe(on_num_sources_change, names='value')

# Widget to input the prompt
prompt_widget = Text(value="", placeholder="Enter your prompt:", description="Prompt:")
display(prompt_widget)

# Widget to select whether to translate the prompt
translate_checkbox = Checkbox(value=False, description="Translate prompt:")
display(translate_checkbox)

# Widget to input the language of the prompt (if translation is selected)
language_widget = Text(value="", placeholder="Enter language of prompt (e.g. ko for Korean):", description="Language:")
display(language_widget)

# Function to run the SmartScraperGraph for each source URL
def smart_scraper_app(b):
    # Get the prompt value
    prompt_value = prompt_widget.value
    # Check if translation is selected
    if translate_checkbox.value:
        # Get the language value
        language_value = language_widget.value
        # Create a Translator instance
        translator = Translator(from_lang="en", to_lang=language_value)
    else:
        translator = None
    # List to store the results
    results = []
    # Loop through each source URL widget
    for source_widget in sources_widgets:
        # Get the source URL value
        source_value = source_widget.value
        # Create a SmartScraperGraph instance
        smart_scraper_graph = SmartScraperGraph(
            prompt=prompt_value,
            source=source_value,
            config=graph_config
        )
        # Run the SmartScraperGraph and get the result
        result = smart_scraper_graph.run()
        # Append the result to the results list
        results.append(result)
    # Convert the results list to JSON
    output_json = json.dumps(results, indent=2)
    # If translation is selected, translate the output in chunks
    if translator:
        chunk_size = 500
        output_translated = ""
        for i in range(0, len(output_json), chunk_size):
            chunk = output_json[i:i + chunk_size]
            output_translated += translator.translate(chunk) + "\n"
        print(f"Translated output in {language_value}: {output_translated}")
    else:
        print("Output in English:")
        print(output_json)

# Button to run the smart_scraper_app function
button = Button(description="Run")
display(button)

# Set the button's on_click event to call the smart_scraper_app function
button.on_click(smart_scraper_app)
# Out:
# IntText(value=1, description='Number of sources:')
# Text(value='', description='Prompt:', placeholder='Enter your prompt:')
# Checkbox(value=False, description='Translate prompt:')
# Text(value='', description='Language:', placeholder='Enter language of prompt (e.g. ko for Korean):')
# Button(description='Run', style=ButtonStyle())
# Text(value='', description='Source 1:', placeholder='Enter source 1 URL:')
# Text(value='', description='Source 2:', placeholder='Enter source 2 URL:')
# Text(value='', description='Source 3:', placeholder='Enter source 3 URL:')
# --- Executing Fetch Node ---
# --- Executing Parse Node ---
# --- Executing RAG Node ---
# --- (updated chunks metadata) ---
# --- (tokens compressed and vector stored) ---
# --- Executing GenerateAnswer Node ---
# Processing chunks: 100%|██████████| 1/1 [00:00<00:00, 2388.56it/s]
# --- Executing Fetch Node ---
# --- Executing Parse Node ---
# --- Executing RAG Node ---
# --- (updated chunks metadata) ---
# ...

# %%
import json
from scrapegraphai.graphs import SmartScraperGraph
from ipywidgets import Text, IntText, Button, Checkbox
from translate import Translator

# Configuration for the SmartScraperGraph
graph_config = {
    "llm": {
        "api_key": "AIzaSyB5T_QRbSSZ4Wgy7oSPMsflO_9I45L6zVg",
        "model": "gemini-pro",
    },
    "verbose": True
}

# Widget to input the number of sources
num_sources_widget = IntText(value=1, description="Number of sources:")
display(num_sources_widget)

# List to store the source URL widgets
sources_widgets = []

# Function to create source URL widgets based on the number of sources
def on_num_sources_change(change):
    # Get the new number of sources
    num_sources = change.new
    # Clear the list of source URL widgets
    sources_widgets.clear()
    # Create a new source URL widget for each source
    for i in range(num_sources):
        source_widget = Text(value="", placeholder=f"Enter source {i+1} URL:", description=f"Source {i+1}:")
        sources_widgets.append(source_widget)
        display(source_widget)

# Observe changes to the number of sources widget and call the on_num_sources_change function
num_sources_widget.observe(on_num_sources_change, names='value')

# Widget to input the prompt
prompt_widget = Text(value="", placeholder="Enter your prompt:", description="Prompt:")
display(prompt_widget)

# Widget to select whether to translate the prompt
translate_checkbox = Checkbox(value=False, description="Translate prompt:")
display(translate_checkbox)

# Widget to input the language of the prompt (if translation is selected)
language_widget = Text(value="", placeholder="Enter language of prompt (e.g. ko for Korean):", description="Language:")
display(language_widget)

# Function to run the SmartScraperGraph for each source URL
def smart_scraper_app(b):
    # Get the prompt value
    prompt_value = prompt_widget.value
    # Check if translation is selected
    if translate_checkbox.value:
        # Get the language value
        language_value = language_widget.value
        # Create a Translator instance
        translator = Translator(from_lang="en", to_lang=language_value)
    else:
        translator = None
    # List to store the results
    results = []
    # Loop through each source URL widget
    for source_widget in sources_widgets:
        # Get the source URL value
        source_value = source_widget.value
        # Create a SmartScraperGraph instance
        smart_scraper_graph = SmartScraperGraph(
            prompt=prompt_value,
            source=source_value,
            config=graph_config
        )
        # Run the SmartScraperGraph and get the result
        result = smart_scraper_graph.run()
        # Append the result to the results list
        results.append(result)
    # Convert the results list to JSON
    output_json = json.dumps(results, indent=2)
    # If translation is selected, translate the output in chunks
    if translator:
        chunk_size = 500
        output_translated = ""
        for i in range(0, len(output_json), chunk_size):
            chunk = output_json[i:i + chunk_size]
            output_translated += translator.translate(chunk) + "\n"
        print(f"Translated output in {language_value}: {output_translated}")
    else:
        print("Output in English:")
        print(output_json)

# Button to run the smart_scraper_app function
button = Button(description="Run")
display(button)

# Set the button's on_click event to call the smart_scraper_app function
button.on_click(smart_scraper_app)
# Out:
# IntText(value=1, description='Number of sources:')
# Text(value='', description='Prompt:', placeholder='Enter your prompt:')
# Checkbox(value=False, description='Translate prompt:')
# Text(value='', description='Language:', placeholder='Enter language of prompt (e.g. ko for Korean):')
# Button(description='Run', style=ButtonStyle())
# Text(value='', description='Source 1:', placeholder='Enter source 1 URL:')
# Text(value='', description='Source 2:', placeholder='Enter source 2 URL:')
# Text(value='', description='Source 3:', placeholder='Enter source 3 URL:')
# --- Executing Fetch Node ---
# --- Executing Parse Node ---
# --- Executing RAG Node ---
# --- (updated chunks metadata) ---
# --- (tokens compressed and vector stored) ---
# --- Executing GenerateAnswer Node ---
# Processing chunks: 100%|██████████| 1/1 [00:00<00:00, 1069.16it/s]
# --- Executing Fetch Node ---
# --- Executing Parse Node ---
# --- Executing RAG Node ---
# --- (updated chunks metadata) ---
# ...
